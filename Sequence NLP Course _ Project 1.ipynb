# %% [markdown]
# #**DOMAIN:** Digital content and entertainment industry
# #**CONTEXT:**
# The objective of this project is to build a text classification model that analyses the customer's sentiments based on their reviews in the IMDB database. The model uses a complex deep learning model to build an embedding layer followed by a classification algorithm to analyse the sentiment of the customers.
# #**DATA DESCRIPTION:**
# The Dataset of 50,000 movie reviews from IMDB, labelled by sentiment (positive/negative). Reviews have been preprocessed, and each review is encoded as a sequence of word indexes (integers). For convenience, the words are indexed by their frequency in the dataset, meaning the for that has index 1 is the most frequent word. Use the first 20 words from each review to speed up training, using a max vocabulary size of 10,000. As a convention, "0" does not stand for a specific word, but instead is used to encode any unknown word.
# #**PROJECT OBJECTIVE:**
# Build a sequential NLP classifier which can use input text parameters to determine the customer sentiments.
#
# #**STEPS AND TASKS:** [ Total Score: 30 points]
# 1. Import and analyse the data set.
#   * Hint: - Use `imdb.load_data()` method
#     * Get train and test set
#     * Take 10000 most frequent words
# 2. Perform relevant sequence adding on the data
# 3. Perform following data analysis:
#   * Print shape of features and labels
#   * Print value of any one feature and it's label
# 4. Decode the feature value to get original sentence
# 5. Design, train, tune and test a sequential model.
#   * Hint: The aim here Is to import the text, process it such a way that it can be taken as an inout to the ML/NN
# classifiers. Be analytical and experimental here in trying new approaches to design the best model.
# 6. Use the designed model to print the prediction on any one sample.

# %% [markdown]
# # 1. Import and analyse the data set
#   * ### Hint: - Use `imdb.load_data()` method
#     * ### Get train and test set
#     * ### Take 10000 most frequent words

# %%
from keras.datasets import imdb

(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words = 10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17465344/17464789 [==============================] - 0s 0us/step
# <string>:6: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/datasets/imdb.py:159: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_train, y_train = np.array(xs[:idx]), np.array(labels[:idx])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/datasets/imdb.py:160: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   x_test, y_test = np.array(xs[idx:]), np.array(labels[idx:])

# %% [markdown]
# # 2. Perform relevant sequence adding on the data

# %%
# taking first 20 words of each review as mentioned above
from tensorflow.keras.preprocessing.sequence import pad_sequences

X_train = pad_sequences(X_train, maxlen = 20)
X_test =  pad_sequences(X_test, maxlen = 20)

# %% [markdown]
# # 3. Perform following data analysis:
#   * ### Print shape of features and labels
#   * ### Print value of any one feature and it's label

# %%
print('Number of reviews :', X_train.shape, X_test.shape)
print('Number of labels :', y_train.shape, y_test.shape)
# Out:
# Number of reviews : (25000, 20) (25000, 20)
# Number of labels : (25000,) (25000,)

# %%
# visualizing the data

print('Feature :', X_train[1])
print('Label :', y_train[1])
# Out:
# Feature : [  23    4 1690   15   16    4 1355    5   28    6   52  154  462   33
#    89   78  285   16  145   95]
# Label : 0

# %% [markdown]
# # 4. Decode the feature value to get original sentence

# %%
word_index = imdb.get_word_index()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb_word_index.json
# 1646592/1641221 [==============================] - 0s 0us/step

# %%
# mapping integers to their respective words

reverse_word_index = dict([(value, key) for (key, value) in word_index.items()])

# %%
# decoding the review

decoded_review = ' '.join([reverse_word_index.get(i-3, '?') for i in X_train[0]])
decoded_review
# Out:
# "story was so lovely because it was true and was someone's life after all that was shared with us all"

# %% [markdown]
# # 5. Design, train, tune and test a sequential model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Flatten, Dense, Dropout

model = Sequential()

# embedding layer
model.add(Embedding(input_dim = 10000, output_dim = 100, input_length = 20))

# recurrent layer
model.add(LSTM(64, activation = 'relu', return_sequences=True))

model.add(Flatten())
model.add(Dense(512, activation = 'relu'))

# dropout for regularization
model.add(Dropout(0.5))
model.add(Dense(256, activation = 'relu'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU

# %%
# compiling
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 20, 100)           1000000
# _________________________________________________________________
# lstm (LSTM)                  (None, 20, 64)            42240
# _________________________________________________________________
# flatten (Flatten)            (None, 1280)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               655872
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 1,829,697
# Trainable params: 1,829,697
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fitting the model
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=30, batch_size=128)
# Out:
# Epoch 1/30
# 196/196 [==============================] - 15s 55ms/step - loss: 0.6197 - accuracy: 0.6227 - val_loss: 0.4766 - val_accuracy: 0.7671
# Epoch 2/30
# 196/196 [==============================] - 10s 50ms/step - loss: 0.3841 - accuracy: 0.8317 - val_loss: 0.4876 - val_accuracy: 0.7634
# Epoch 3/30
# 196/196 [==============================] - 10s 52ms/step - loss: 0.3051 - accuracy: 0.8757 - val_loss: 0.5931 - val_accuracy: 0.7473
# Epoch 4/30
# 196/196 [==============================] - 10s 51ms/step - loss: 0.2019 - accuracy: 0.9221 - val_loss: 0.7320 - val_accuracy: 0.7397
# Epoch 5/30
# 196/196 [==============================] - 10s 52ms/step - loss: 0.1204 - accuracy: 0.9556 - val_loss: 0.9594 - val_accuracy: 0.7323
# Epoch 6/30
# 196/196 [==============================] - 10s 50ms/step - loss: 0.0701 - accuracy: 0.9748 - val_loss: 1.2692 - val_accuracy: 0.7207
# Epoch 7/30
# 196/196 [==============================] - 10s 51ms/step - loss: 0.0448 - accuracy: 0.9845 - val_loss: 1.5949 - val_accuracy: 0.7216
# Epoch 8/30
# 196/196 [==============================] - 10s 51ms/step - loss: 0.0333 - accuracy: 0.9887 - val_loss: 1.8154 - val_accuracy: 0.7243
# Epoch 9/30
# 196/196 [==============================] - 10s 52ms/step - loss: 0.0239 - accuracy: 0.9922 - val_loss: 2.0071 - val_accuracy: 0.7233
# Epoch 10/30
# 196/196 [==============================] - 10s 51ms/step - loss: 0.0158 - accuracy: 0.9947 - val_loss: 2.0241 - val_accuracy: 0.7226
# Epoch 11/30
# 196/196 [==============================] - 10s 52ms/step - loss: 0.0188 - accuracy: 0.9930 - val_loss: 2.1823 - val_accuracy: 0.7206
# Epoch 12/30
# 196/196 [==============================] - 10s 52ms/step - loss: 0.0140 - accuracy: 0.9952 - val_loss: 2.5086 - val_accuracy: 0.7246
# Epoch 13/30
# 196/196 [==============================] - 10s 53ms/step - loss: 0.0119 - accuracy: 0.9963 - val_loss: 2.5848 - val_accuracy: 0.7194
# Epoch 14/30
# 196/196 [==============================] - 10s 51ms/step - loss: 0.0094 - accuracy: 0.9966 - val_loss: 2.6881 - val_accuracy: 0.7235
# Epoch 15/30
# 196/196 [==============================] - 10s 50ms/step - loss: 0.0046 - accuracy: 0.9985 - val_loss: 2.7079 - val_accuracy: 0.7218
# Epoch 16/30
# 196/196 [==============================] - 10s 52ms/step - loss: 0.0120 - accuracy: 0.9958 - val_loss: 2.6768 - val_accuracy: 0.7254
# Epoch 17/30
# 196/196 [==============================] - 10s 51ms/step - loss: 0.0070 - accuracy: 0.9972 - val_loss: 2.9474 - val_accuracy: 0.7188
# Epoch 18/30
# 196/196 [==============================] - 10s 52ms/step - loss: 0.0116 - accuracy: 0.9959 - val_loss: 2.7065 - val_accuracy: 0.7207
# Epoch 19/30
# 196/196 [==============================] - 10s 52ms/step - loss: 0.0064 - accuracy: 0.9979 - val_loss: 2.6459 - val_accuracy: 0.7218
# Epoch 20/30
# 196/196 [==============================] - 10s 51ms/step - loss: 0.0054 - accuracy: 0.9982 - val_loss: 2.9081 - val_accuracy: 0.7212
# Epoch 21/30
# 196/196 [==============================] - 10s 51ms/step - loss: 0.0093 - accuracy: 0.9971 - val_loss: 2.8066 - val_accuracy: 0.7189
# Epoch 22/30
# 196/196 [==============================] - 10s 50ms/step - loss: 0.0050 - accuracy: 0.9986 - val_loss: 2.9600 - val_accuracy: 0.7181
# Epoch 23/30
# 196/196 [==============================] - 10s 51ms/step - loss: 0.0052 - accuracy: 0.9982 - val_loss: 3.0860 - val_accuracy: 0.7205
# Epoch 24/30
# 196/196 [==============================] - 10s 50ms/step - loss: 0.0025 - accuracy: 0.9990 - val_loss: 3.7982 - val_accuracy: 0.7222
# Epoch 25/30
# 196/196 [==============================] - 10s 50ms/step - loss: 0.0096 - accuracy: 0.9971 - val_loss: 3.3754 - val_accuracy: 0.7189
# Epoch 26/30
# 196/196 [==============================] - 10s 49ms/step - loss: 0.0028 - accuracy: 0.9991 - val_loss: 3.1897 - val_accuracy: 0.7176
# Epoch 27/30
# 196/196 [==============================] - 10s 51ms/step - loss: 0.0068 - accuracy: 0.9977 - val_loss: 3.4464 - val_accuracy: 0.7216
# Epoch 28/30
# 196/196 [==============================] - 10s 51ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 3.2682 - val_accuracy: 0.7230
# Epoch 29/30
# 196/196 [==============================] - 10s 51ms/step - loss: 0.0073 - accuracy: 0.9976 - val_loss: 3.4780 - val_accuracy: 0.7196
# Epoch 30/30
# 196/196 [==============================] - 10s 50ms/step - loss: 0.0075 - accuracy: 0.9977 - val_loss: 3.4423 - val_accuracy: 0.7172

# %%
score = model.evaluate(X_test, y_test)
print('Loss : ', score[0], 'Accuracy: ', score[1])
# Out:
# 782/782 [==============================] - 3s 4ms/step - loss: 3.4423 - accuracy: 0.7172
# Loss :  3.442291498184204 Accuracy:  0.7172399759292603

# %% [markdown]
# # 6. Use the designed model to print the prediction on any one sample

# %%
result = model.predict(X_test[0].reshape((1, 20)))

# %%
result
# Out:
# array([[0.2746454]], dtype=float32)
