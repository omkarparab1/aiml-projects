# %%
import pandas as pd
df=pd.read_csv('laliga.csv')
df=df.replace('-',0)
df
# Out:
#     Pos              Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 0     1       Real Madrid       86   4385        2762     1647        552
# 1     2         Barcelona       86   4262        2762     1581        573
# 2     3   Atletico Madrid       80   3442        2614     1241        598
# 3     4          Valencia       82   3386        2664     1187        616
# 4     5   Athletic Bilbao       86   3368        2762     1209        633
# ..  ...               ...      ...    ...         ...      ...        ...
# 56   57             Xerez        1     34          38        8         10
# 57   58            Condal        1     22          30        7          8
# 58   59   Atletico Tetuan        1     19          30        7          5
# 59   60  Cultural Leonesa        1     14          30        5          4
# 60   61            Girona        1      0           0        0          0
#
#    GamesLost GoalsFor GoalsAgainst Champion Runner-up Third Fourth Fifth  \
# ...

# %%
df['DebutNew']=df['Debut'].str[:4] #making a new column for debut in order to slice values based on year
df[(df['DebutNew']>='1930') & (df['DebutNew']<='1980')]
# Out:
#     Pos                 Team  Seasons Points GamesPlayed GamesWon GamesDrawn  \
# 3     4             Valencia       82   3386        2664     1187        616
# 5     6              Sevilla       73   2819        2408      990        531
# 8     9             Zaragoza       58   2109        1986      698        522
# 9    10           Real Betis       51   1884        1728      606        440
# 10   11  Deportivo La Coruna       45   1814        1530      563        392
# 11   12           Celta Vigo       51   1789        1698      586        389
# 12   13           Valladolid       42   1471        1466      463        384
# 14   15       Sporting Gijon       43   1389        1458      471        358
# 15   16              Osasuna       37   1351        1318      426        327
# 16   17               Malaga       36   1314        1255      390        330
# 17   18               Oviedo       38   1174        1192      408        292
# ...

# %%
df['Points']=df['Points'].astype(int)
df.sort_values('Points',ascending=False,inplace=True)
df[['Team','Points']].head()
# Out:
#               Team  Points
# 0      Real Madrid    4385
# 1        Barcelona    4262
# 2  Atletico Madrid    3442
# 3         Valencia    3386
# 4  Athletic Bilbao    3368

# %%
def Goal_diff_count():
    df['GoalDiff']=df['GoalsFor'].astype(int)-df['GoalsAgainst'].astype('int')
    print(df[['Team','GoalDiff']])
    print('Max Goal Difference: ',max(df['GoalDiff']))
    print('Min Goal Difference: ',min(df['GoalDiff']))
Goal_diff_count()
# Out:
#                 Team  GoalDiff
# 0        Real Madrid      2807
# 1          Barcelona      2786
# 2    Atletico Madrid      1225
# 3           Valencia       929
# 4    Athletic Bilbao       931
# ..               ...       ...
# 55           Leganes       -19
# 56             Xerez       -28
# 54            Lleida      -112
# 59  Cultural Leonesa       -31
# 60            Girona         0
#
# [61 rows x 2 columns]
# Max Goal Difference:  2807
# Min Goal Difference:  -525

# %%
df['WinningPercent']=df['GamesWon'].astype(int)/df['GamesPlayed'].astype(int)*100
df['WinningPercent']=df['WinningPercent'].fillna(0)
df.sort_values('WinningPercent',ascending=False,inplace=True)
df[['Team','WinningPercent']].head()
# Out:
#               Team  WinningPercent
# 0      Real Madrid       59.630702
# 1        Barcelona       57.241130
# 2  Atletico Madrid       47.475134
# 3         Valencia       44.557057
# 4  Athletic Bilbao       43.772629

# %%
df2=df.groupby(['BestPosition']).sum()
print(df2.loc[:,['Points']])
# Out:
#               Points
# BestPosition
# 1              27933
# 2               6904
# 3               5221
# 4               6563
# 5               1884
# 6               2113
# 7               1186
# 8               1134
# 9                 96
# 10               450
# 11               445
# 12               511
# 14                71
# 15                14
# 16                81
# 17               266
# 19                81
# 20                34
