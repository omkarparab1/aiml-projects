# %% [markdown]
# ![alt text](https://drive.google.com/uc?export=view&id=1UXScsVx_Wni_JuDdB8LeTnM6jsPfIwkW)
#
# Proprietary content. © Great Learning. All Rights Reserved. Unauthorized use or distribution prohibited.

# %% [markdown]
# # Mobile Phone Detection in an Image
#
# ## Domain
# Mobile Phones, Computer Vision
#
# ## Business Context
# The ability to process visual information using machine learning algorithms can be very useful. Electronics companies can use it to identify the presence of a mobile in an image (location), mobile brand just by looking at the image, and minor damages if there are any. The computer vision field has multiple applications and based on the available data it can be used to meet business objectives.
# Here, we will use a simple convolutional neural network to classify images with and without mobile phones.
#
# ## Objective
#
# Given the images and label whether an image has a mobile phone or not, can you train a model that allows you to map and find the presence of mobile phones within the selected images.

# %% [markdown]
# ### Package version
# - tensorflow==2.3.0
# - matplotlib==3.2.1
# - h5py==2.10.0
# - google==2.0.3

# %% [markdown]
# ## Table of Content
#
# 1. Import Libraries
#
# 2. Setting options
#
# 3. Data loading and Data Analysis
#
# 4. Visualize and Standardize the data
#
# 5. Model Building
#
# 6. Evaluate Model
#
# 7. Conclusion and Interpretation

# %% [markdown]
# ## 1. Import Libraries

# %% [markdown]
# Let us start by mounting the drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Let us check for the version of installed tensorflow.

# %%
# used to supress display of warnings
import warnings

# os is used to provide a way of using operating system dependent functionality
# We use it for setting working folder
import os

# Pandas is used for data manipulation and analysis
import pandas as pd 

# Numpy is used for large, multi-dimensional arrays and matrices, along with mathematical operators on these arrays
import numpy as np

# Matplotlib is a data visualization library for 2D plots of arrays, built on NumPy arrays 
# and designed to work with the broader SciPy stack
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import pyplot

# Seaborn is based on matplotlib, which aids in drawing attractive and informative statistical graphics.
import seaborn as sns
import tensorflow 
print(tensorflow.__version__)


from keras.utils import np_utils
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.optimizers import SGD
from keras.constraints import maxnorm
from PIL import Image
from PIL import ImageMath
# Out:
# 2.4.1

# %% [markdown]
# ## 2. Setting Options

# %%
# suppress display of warnings
warnings.filterwarnings('ignore')

# display all dataframe columns
pd.options.display.max_columns = None

# display all dataframe rows
pd.options.display.max_rows = None

# %% [markdown]
# ## 3. Data loading and Data Analysis

# %%
import cv2
no_mobile_path =  "/content/drive/MyDrive/mobile-images/no-mobile"
yes_mobile_path =  "/content/drive/MyDrive/mobile-images/yes-mobile"
print("No mobile images :" , len(os.listdir(no_mobile_path)))
print("Yes mobile images :", len(os.listdir(yes_mobile_path)))
# Out:
# No mobile images : 121
# Yes mobile images : 124

# %% [markdown]
# ### Read images and save the pixel information to an array. Also, save their corresponding label to a list ( YES-Mobile - 1, NO-Mobile - 0). Resize the images to shape (128, 128, 3).

# %%
yes_mobile = os.listdir(yes_mobile_path)

x_yes = []
y_yes = []

for i in yes_mobile:
  img = cv2.imread(os.path.join(yes_mobile_path, i))
  img = cv2.resize(img,(128,128))
  x_yes.append(img)
  y_yes.append(1)

# %%
no_mobile = os.listdir(no_mobile_path)

x_no = []
y_no = []

for i in no_mobile:
  img = cv2.imread(os.path.join(no_mobile_path, i))
  img = cv2.resize(img,(128,128))
  x_no.append(img)
  y_no.append(0)

# %% [markdown]
# ### Check shape and size of the images

# %%
print(x_yes[0].shape)
print(x_no[0].shape)
print(y_yes[0])
print(y_no[0])
# Out:
# (128, 128, 3)
# (128, 128, 3)
# 1
# 0

# %% [markdown]
# ###  What is the percentage of images with and without mobile phone in the data

# %%
len(os.listdir(no_mobile_path)) / (len(os.listdir(no_mobile_path)) + len(os.listdir(yes_mobile_path)))
# Out:
# 0.49387755102040815

# %%
len(os.listdir(yes_mobile_path)) / (len(os.listdir(no_mobile_path)) + len(os.listdir(yes_mobile_path)))
# Out:
# 0.5061224489795918

# %% [markdown]
# ### Concatenate above two arrays (array having image details of with and without mobile) into one variable and check the final size of the data
# ### Concatenate lists having label data into one list

# %%
X = np.concatenate((x_yes, x_no), axis = 0)
Y = np.concatenate((y_yes, y_no), axis = 0)

print(X.shape)
print(Y.shape)
# Out:
# (245, 128, 128, 3)
# (245,)

# %% [markdown]
# ### Shuffle the above data and labels ( Data and label should be in sync)

# %%
from sklearn.utils import shuffle

X, Y = shuffle(X, Y, random_state=0)

# %% [markdown]
# ## 4. Visualize and Standardize the data

# %% [markdown]
# ### Visualise the first 10 images in the data and print their corresponding labels.

# %%
for i in range(10):
  label = Y[i]
  img = X[i]
  print('This is:',label)
  plt.imshow(img);
  plt.show()
# Out:
# This is: 0
# This is: 1
# This is: 1
# This is: 0
# This is: 0
# This is: 1
# This is: 0
# This is: 1
# This is: 0
# This is: 1

# %% [markdown]
# ### Split the data into train and test

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=0)

# %% [markdown]
# ### Print shape of the X train and X test data

# %%
print(X_train.shape, X_test.shape)
print(y_train.shape, y_test.shape)
# Out:
# (171, 128, 128, 3) (74, 128, 128, 3)
# (171,) (74,)

# %% [markdown]
# ### Normalize the data by dividing by 255

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

X_train /= 255
X_test /= 255

print(X_train)
print(X_test)
# Out:
# [[[[0.5294118  0.5294118  0.5294118 ]
#    [0.5254902  0.5254902  0.5254902 ]
#    [0.5254902  0.5254902  0.5254902 ]
#    ...
#    [0.56078434 0.56078434 0.56078434]
#    [0.5647059  0.5647059  0.5647059 ]
#    [0.5647059  0.5647059  0.5647059 ]]
#
#   [[0.52156866 0.52156866 0.52156866]
#    [0.5176471  0.5176471  0.5176471 ]
#    [0.5176471  0.5176471  0.5176471 ]
#    ...
#    [0.5647059  0.5647059  0.5647059 ]
#    [0.5686275  0.5686275  0.5686275 ]
#    [0.5686275  0.5686275  0.5686275 ]]
#
#   [[0.50980395 0.50980395 0.50980395]
#    [0.50980395 0.50980395 0.50980395]
#    [0.50980395 0.50980395 0.50980395]
#    ...
#    [0.5647059  0.5647059  0.5647059 ]
#    [0.5686275  0.5686275  0.5686275 ]
#    [0.5686275  0.5686275  0.5686275 ]]
#
#   ...
#
#   [[0.4627451  0.4627451  0.4627451 ]
#    [0.4745098  0.4745098  0.4745098 ]
#    [0.4862745  0.4862745  0.4862745 ]
#    ...
#    [0.58431375 0.58431375 0.58431375]
#    [0.58431375 0.58431375 0.58431375]
#    [0.58431375 0.58431375 0.58431375]]
#
#   [[0.6862745  0.6862745  0.6862745 ]
#    [0.6901961  0.6901961  0.6901961 ]
#    [0.7019608  0.7019608  0.7019608 ]
#    ...
#    [0.77254903 0.77254903 0.77254903]
#    [0.76862746 0.76862746 0.76862746]
#    [0.76862746 0.76862746 0.76862746]]
#
#   [[0.98039216 0.98039216 0.98039216]
#    [0.9843137  0.9843137  0.9843137 ]
#    [0.99215686 0.99215686 0.99215686]
#    ...
#    [1.         1.         1.        ]
#    [1.         1.         1.        ]
#    [1.         1.         1.        ]]]
#
#
#  [[[0
.68235296 0.68235296 0.68235296]
#    [0.68235296 0.68235296 0.68235296]
#    [0.68235296 0.68235296 0.68235296]
#    ...
#    [0.68235296 0.68235296 0.68235296]
#    [0.68235296 0.68235296 0.68235296]
#    [0.68235296 0.68235296 0.68235296]]
#
#   [[0.68235296 0.68235296 0.68235296]
#    [0.68235296 0.68235296 0.68235296]
#    [0.68235296 0.68235296 0.68235296]
#    ...
#    [0.68235296 0.68235296 0.68235296]
#    [0.68235296 0.68235296 0.68235296]
#    [0.68235296 0.68235296 0.68235296]]
#
#   [[0.68235296 0.68235296 0.68235296]
#    [0.68235296 0.68235296 0.68235296]
#    [0.68235296 0.68235296 0.68235296]
#    ...
#    [0.68235296 0.68235296 0.68235296]
#    [0.68235296 0.68235296 0.68235296]
#    [0.68235296 0.68235296 0.68235296]]]]

# %% [markdown]
# ###  One hot encode the labels for train and test data
# Hint:- We need to one hot encode the labels for the model to understand the labels better. We will be using categorical cross entropy as our loss function and for this purpose we need our labels to be in one hot encoded format.

# %%
import tensorflow as tf
import keras
trainY = tf.keras.utils.to_categorical(y_train, num_classes=2)
testY = tf.keras.utils.to_categorical(y_test, num_classes=2)

# %% [markdown]
# ## 5. Model building

# %% [markdown]
# ### Define the model architecture using TensorFlow with a Conv2D layer followed by dense layers with activation as ReLu and softmax respectively.

# %%
from keras.utils import np_utils
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.optimizers import SGD


row ,col = 128,128
channel = 3
n_classes = 2
n_epochs = 50
batch_size = 32


model = Sequential()
model.add(Conv2D(32, kernel_size = 3 , activation= 'relu', input_shape = (row,col,channel)))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(64, kernel_size = 3 , activation= 'relu'))
model.add(MaxPooling2D((2,2)))
model.add(Flatten())
model.add(Dense(n_classes , activation= 'softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_5 (Conv2D)            (None, 126, 126, 32)      896
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 63, 63, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 61, 61, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 57600)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 115202
# =================================================================
# Total params: 134,594
# Trainable params: 134,594
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the above model using appropriate loss metric. Try with sgd, adam optimizer and "accuracy" as metrics.

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# ### Fit the model on the training dataset along with it's equivalent one hot encoded labels

# %%
training_history = model.fit(X_train, trainY, validation_data= (X_test, testY), epochs= n_epochs, batch_size= batch_size)
# Out:
# Epoch 1/50
# 6/6 [==============================] - 1s 53ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.9024 - val_accuracy: 0.8649
# Epoch 2/50
# 6/6 [==============================] - 0s 28ms/step - loss: 0.0127 - accuracy: 0.9926 - val_loss: 0.7606 - val_accuracy: 0.8784
# Epoch 3/50
# 6/6 [==============================] - 0s 26ms/step - loss: 0.0569 - accuracy: 0.9763 - val_loss: 0.7730 - val_accuracy: 0.8784
# Epoch 4/50
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0143 - accuracy: 0.9948 - val_loss: 0.5496 - val_accuracy: 0.9189
# Epoch 5/50
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0042 - accuracy: 1.0000 - val_loss: 0.4973 - val_accuracy: 0.9189
# Epoch 6/50
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.6166 - val_accuracy: 0.8919
# Epoch 7/50
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.7564 - val_accuracy: 0.8784
# Epoch 8/50
# 6/6 [==============================] - 0s 25ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.6419 - val_accuracy: 0.8784
# Epoch 9/50
# 6/6 [==============================] - 0s 24ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.6035 - val_accuracy: 0.9054
# Epoch 10/50
# 6/6 [==============================] - 0s 25ms/step - loss: 4.1635e-04 - accuracy: 1.0000 - val_loss: 0.5976 - val_accuracy: 0.9189
# Epoch 11/50
# 6/6 [==============================] - 0s 26ms/step - loss: 4.1959e-04 - accuracy: 1.0000 - val_loss: 0.5996 - val_accuracy: 0.9189
# Epoch 12/50
# 6/6 [==============================] - 0s 25ms/step - loss: 3.2319e-04 - accuracy: 1.0000 - val_loss: 0.6120 - val_accuracy: 0.9189
# Epoch 13/50
# 6/6 [==============================] - 0s 24ms/step - loss: 2.2624e-04 - accuracy: 1.0000 - val_loss: 0.6250 - val_accuracy: 0.8919
# Epoch 14/50
# 6/6 [==============================] - 0s 23ms/step - loss: 2.8730e-04 - accuracy: 1.0000 - val_loss: 0.6276 - val_accuracy: 0.9054
# Epoch 15/50
# 6/6 [==============================] - 0s 25ms/step - loss: 2.4722e-04 - accuracy: 1.0000 - val_loss: 0.6265 - val_accuracy: 0.9189
# Epoch 16/50
# 6/6 [==============================] - 0s 25ms/step - loss: 2.1254e-04 - accuracy: 1.0000 - val_loss: 0.6319 - val_accuracy: 0.9189
# Epoch 17/50
# 6/6 [==============================] - 0s 25ms/step - loss: 1.5041e-04 - accuracy: 1.0000 - val_loss: 0.6385 - val_accuracy: 0.9189
# Epoch 18/50
# 6/6 [==============================] - 0s 25ms/step - loss: 1.7581e-04 - accuracy: 1.0000 - val_loss: 0.6462 - val_accuracy: 0.9189
# Epoch 19/50
# 6/6 [==============================] - 0s 25ms/step - loss: 1.8828e-04 - accuracy: 1.0000 - val_loss: 0.6528 - val_accuracy: 0.9189
# Epoch 20/50
# 6/6 [==============================] - 0s 24ms/step - loss: 1.7253e-04 - accuracy: 1.0000 - val_loss: 0.6566 - val_accuracy: 0.9189
# Epoch 21/50
# 6/6 [==============================] - 0s 25ms/step - loss: 1.4445e-04 - accuracy: 1.0000 - val_loss: 0.6612 - val_accuracy: 0.9189
# Epoch 22/50
# 6/6 [==============================] - 0s 25ms/step - loss: 1.1399e-04 - accuracy: 1.0000 - val_loss: 0.6663 - val_accuracy: 0.9189
# Epoch 23/50
# 6/6 [==============================] - 0s 24ms/step - loss: 1.4337e-04 - accuracy: 1.0000 - val_loss: 0.6716 - val_accuracy: 0.9189
# Epoch 24/50
# 6/6 [==============================] - 0s 24ms/step - loss: 9.9273e-05 - accuracy: 1.0000 - val_loss: 0.6764 - val_accuracy: 0.9189
# Epoch 25/50
# 6/6 [==============================] - 0s 24ms/step - loss: 1.4016e-04 - accuracy: 1.0000 - val_loss: 0.6812 - val_accuracy: 0.9189
# Epoch 26/50
# 6/6 [==============================] - 0s 24ms/step - loss: 1.1237e-04 - accuracy: 1.0000 - val_loss: 0.6856 - val_accuracy: 0.9054
# Epoch 27/50
# 6/6 [==============================] - 0s 25ms/step - loss: 7.6090e-05 - accuracy: 1.0000 - val_loss: 0.6895 - val_accuracy: 0.9054
# Epoch 28/50
# 6/6 [==============================] - 0s 25ms/step - loss: 1.0985e-04 - accuracy: 1.0000 - val_loss: 0.6941 - val_accuracy: 0.9054
# Epoch 29/50
# 6/6 [==============================] - 0s 24ms/step - loss: 9.9357e-05 - accuracy: 1.0000 - val_loss: 0.6980 - val_accuracy: 0.9054
# Epoch 30/50
# 6/6 [==============================] - 0s 24ms/step - loss: 7.4656e-05 - accuracy: 1.0000 - val_loss: 0.7012 - val_accuracy: 0.9054
# Epoch 31/50
# 6/6 [==============================] - 0s 24ms/step - loss: 1.0542e-04 - accuracy: 1.0000 - val_loss: 0.7054 - val_accuracy: 0.9054
# Epoch 32/50
# 6/6 [==============================] - 0s 24ms/step - loss: 1.1151e-04 - accuracy: 1.0000 - val_loss: 0.7089 - val_accuracy: 0.9054
# Epoch 33/50
# 6/6 [==============================] - 0s 26ms/step - loss: 8.3926e-05 - accuracy: 1.0000 - val_loss: 0.7108 - val_accuracy: 0.9054
# Epoch 34/50
# 6/6 [==============================] - 0s 24ms/step - loss: 6.0807e-05 - accuracy: 1.0000 - val_loss: 0.7128 - val_accuracy: 0.9054
# Epoch 35/50
# 6/6 [==============================] - 0s 27ms/step - loss: 9.8740e-05 - accuracy: 1.0000 - val_loss: 0.7163 - val_accuracy: 0.9054
# Epoch 36/50
# 6/6 [==============================] - 0s 25ms/step - loss: 7.4434e-05 - accuracy: 1.0000 - val_loss: 0.7195 - val_accuracy: 0.9054
# Epoch 37/50
# 6/6 [==============================] - 0s 25ms/step - loss: 7.0243e-05 - accuracy: 1.0000 - val_loss: 0.7220 - val_accuracy: 0.9054
# Epoch 38/50
# 6/6 [==============================] - 0s 25ms/step - loss: 6.7336e-05 - accuracy: 1.0000 - val_loss: 0.7253 - val_accuracy: 0.9054
# Epoch 39/50
# 6/6 [==============================] - 0s 25ms/step - loss: 6.5913e-05 - accuracy: 1.0000 - val_loss: 0.7278 - val_accuracy: 0.9054
# Epoch 40/50
# 6/6 [==============================] - 0s 26ms/step - loss: 6.0402e-05 - accuracy: 1.0000 - val_loss: 0.7296 - val_accuracy: 0.9054
# Epoch 41/50
# 6/6 [==============================] - 0s 25ms/step - loss: 6.3585e-05 - accuracy: 1.0000 - val_loss: 0.7318 - val_accuracy: 0.9054
# Epoch 42/50
# 6/6 [==============================] - 0s 24ms/step - loss: 6.5572e-05 - accuracy: 1.0000 - val_loss: 0.7342 - val_accuracy: 0.9054
# Epoch 43/50
# 6/6 [==============================] - 0s 24ms/step - loss: 6.5041e-05 - accuracy: 1.0000 - val_loss: 0.7369 - val_accuracy: 0.9054
# Epoch 44/50
# 6/6 [==============================] - 0s 25ms/step - loss: 6.3468e-05 - accuracy: 1.0000 - val_loss: 0.7392 - val_accuracy: 0.9054
# Epoch 45/50
# 6/6 [==============================] - 0s 25ms/step - loss: 6.9747e-05 - accuracy: 1.0000 - val_loss: 0.7401 - val_accuracy: 0.9054
# Epoch 46/50
# 6/6 [==============================] - 0s 25ms/step - loss: 5.0929e-05 - accuracy: 1.0000 - val_loss: 0.7415 - val_accuracy: 0.9054
# Epoch 47/50
# 6/6 [==============================] - 0s 25ms/step - loss: 6.2452e-05 - accuracy: 1.0000 - val_loss: 0.7424 - val_accuracy: 0.9054
# Epoch 48/50
# 6/6 [==============================] - 0s 25ms/step - loss: 6.5695e-05 - accuracy: 1.0000 - val_loss: 0.7430 - val_accuracy: 0.9054
# Epoch 49/50
# 6/6 [==============================] - 0s 25ms/step - loss: 4.8262e-05 - accuracy: 1.0000 - val_loss: 0.7448 - val_accuracy: 0.9054
# Epoch 50/50
# 6/6 [==============================] - 0s 23ms/step - loss: 6.2987e-05 - accuracy: 1.0000 - val_loss: 0.7471 - val_accuracy: 0.9054

# %% [markdown]
# ## 6. Evaluate the model

# %% [markdown]
# ### Evaluate the model on test data and print loss and accuracy

# %%
metric = model.evaluate(X_test, testY)
print("Loss :", metric[0])
print("Accuracy :", metric[1])
# Out:
# 3/3 [==============================] - 0s 6ms/step - loss: 0.7471 - accuracy: 0.9054
# Loss : 0.7471449375152588
# Accuracy : 0.9054054021835327

# %% [markdown]
# ### Predict label data of the test data and check confusion matrix

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, 1)

from sklearn.metrics import confusion_matrix , classification_report
print(confusion_matrix(np.argmax(testY,1), y_pred))

print("-" * 100)
print(classification_report(np.argmax(testY,1), y_pred))
# Out:
# [[33  3]
#  [ 4 34]]
# ----------------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#            0       0.89      0.92      0.90        36
#            1       0.92      0.89      0.91        38
#
#     accuracy                           0.91        74
#    macro avg       0.91      0.91      0.91        74
# weighted avg       0.91      0.91      0.91        74

# %% [markdown]
# ### Display test images and their predicted label for a few samples

# %%
for i in range(5):
  label = y_pred[i]
  actual = y_test[i]
  img = X_test[i]
  print('This is {} and predited label is {}' .format(actual,label))
  plt.imshow(img);
  plt.show()
# Out:
# This is 0 and predited label is 1
# This is 0 and predited label is 0
# This is 0 and predited label is 1
# This is 1 and predited label is 1
# This is 1 and predited label is 1

# %%
for i in range(X_test.shape[0]):
  label = y_pred[i]
  actual = y_test[i]
  if label != actual:
    img = X_test[i]
    print('This is {} and predited label is {}' .format(actual,label) )
    plt.imshow(img);
    plt.show()
# Out:
# This is 0 and predited label is 1
# This is 0 and predited label is 1
# This is 1 and predited label is 0
# This is 0 and predited label is 1
# This is 1 and predited label is 0
# This is 1 and predited label is 0
# This is 1 and predited label is 0

# %% [markdown]
# ### Print following plots
# 1. Plot training accuracy vs validation accuracy
# 2. Plot training loss vs validation loss

# %%
training_accuracy = training_history.history['accuracy']
validation_accuracy = training_history.history['val_accuracy']
training_loss = training_history.history['loss']
validation_loss = training_history.history['val_loss']

# %%
fig, axs = plt.subplots()
axs.set_ylim([-0.5,2])
plt.plot(training_history.history['accuracy'])
plt.plot(training_history.history['val_accuracy'])
plt.plot(training_history.history['loss'])
plt.plot(training_history.history['val_loss'])
plt.title('model accuracy')
plt.ylabel('accuracy / loss')
plt.xlabel('epoch')
plt.legend(['training_accuracy', 'val_accuracy', 'train_loss','val_loss'], loc='best')
plt.show()

# %% [markdown]
# ## 7.  Conclusion and Interpretation

# %% [markdown]
# ### Write your observations and findings
