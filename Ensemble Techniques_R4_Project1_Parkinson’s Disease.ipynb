# %% [markdown]
# # 1. Load the dataset

# %%
import pandas as pd

# %%
df = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/parkinsons/parkinsons.data')
df.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1      119.992       157.302        74.997         0.00784
# 1  phon_R01_S01_2      122.400       148.650       113.819         0.00968
# 2  phon_R01_S01_3      116.682       131.111       111.555         0.01050
# 3  phon_R01_S01_4      116.676       137.871       111.366         0.00997
# 4  phon_R01_S01_5      116.014       141.781       110.655         0.01284
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0           0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1           0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2           0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3           0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4           0.00011   0.00655   0.00908     0.01966       0.06425  ...
#
#    Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# ...

# %% [markdown]
# # 2. It is always a good practice to eye-ball raw data to get a feel of the data in terms of number of structure of the file, number of attributes, types of attributes and a general idea of likely challenges in the dataset. (2.5 points)

# %%
df.sample(10)
# Out:
#                name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 139  phon_R01_S33_6      116.150       131.731       109.815         0.00381
# 27   phon_R01_S06_4      146.845       208.701        81.737         0.00496
# 21   phon_R01_S05_4      153.880       172.860        78.128         0.00480
# 88   phon_R01_S21_5      173.898       211.350        74.677         0.00448
# 173  phon_R01_S43_3      113.715       116.443        96.913         0.00349
# 84   phon_R01_S21_1      176.858       205.560        75.344         0.00747
# 99   phon_R01_S24_3      126.512       141.756        99.770         0.01936
# 177  phon_R01_S44_1      151.737       190.204       129.859         0.00314
# 162  phon_R01_S39_4      114.554       126.778        91.121         0.00651
# 118  phon_R01_S27_4      178.285       442.824        82.063         0.00462
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              195 non-null    object
#  1   MDVP:Fo(Hz)       195 non-null    float64
#  2   MDVP:Fhi(Hz)      195 non-null    float64
#  3   MDVP:Flo(Hz)      195 non-null    float64
#  4   MDVP:Jitter(%)    195 non-null    float64
#  5   MDVP:Jitter(Abs)  195 non-null    float64
#  6   MDVP:RAP          195 non-null    float64
#  7   MDVP:PPQ          195 non-null    float64
#  8   Jitter:DDP        195 non-null    float64
#  9   MDVP:Shimmer      195 non-null    float64
#  10  MDVP:Shimmer(dB)  195 non-null    float64
#  11  Shimmer:APQ3      195 non-null    float64
#  12  Shimmer:APQ5      195 non-null    float64
#  13  MDVP:APQ          195 non-null    float64
#  14  Shimmer:DDA       195 non-null    float64
#  15  NHR               195 non-null    float64
# ...

# %%
df.shape
# Out:
# (195, 24)

# %%
df.isna().any()
# Out:
# name                False
# MDVP:Fo(Hz)         False
# MDVP:Fhi(Hz)        False
# MDVP:Flo(Hz)        False
# MDVP:Jitter(%)      False
# MDVP:Jitter(Abs)    False
# MDVP:RAP            False
# MDVP:PPQ            False
# Jitter:DDP          False
# MDVP:Shimmer        False
# MDVP:Shimmer(dB)    False
# Shimmer:APQ3        False
# Shimmer:APQ5        False
# MDVP:APQ            False
# Shimmer:DDA         False
# NHR                 False
# HNR                 False
# status              False
# RPDE                False
# DFA                 False
# spread1             False
# spread2             False
# D2                  False
# PPE                 False
# dtype: bool

# %%
df.describe()
# Out:
#        MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# count   195.000000    195.000000    195.000000      195.000000
# mean    154.228641    197.104918    116.324631        0.006220
# std      41.390065     91.491548     43.521413        0.004848
# min      88.333000    102.145000     65.476000        0.001680
# 25%     117.572000    134.862500     84.291000        0.003460
# 50%     148.790000    175.829000    104.315000        0.004940
# 75%     182.769000    224.205500    140.018500        0.007365
# max     260.105000    592.030000    239.170000        0.033160
#
#        MDVP:Jitter(Abs)    MDVP:RAP    MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# count        195.000000  195.000000  195.000000  195.000000    195.000000
# mean           0.000044    0.003306    0.003446    0.009920      0.029709
# std            0.000035    0.002968    0.002759    0.008903      0.018857
# min            0.000007    0.000680    0.000920    0.002040      0.009540
# ...

# %% [markdown]
# ### Dataset has 195 rows and 24 columns, except name all other columns have int or float values, status has binary values, there are no null or missing values present in the dataset

# %% [markdown]
# # 3. Using univariate & bivariate analysis to check the individual attributes for their basic statistics such as central values, spread, tails etc. What are your observations? (15 points)

# %%
import seaborn as sns
sns.distplot(df['MDVP:Fo(Hz)'])

# %%
sns.distplot(df['MDVP:Fhi(Hz)'])

# %%
sns.distplot(df['MDVP:Flo(Hz)'])

# %%
sns.distplot(df['MDVP:Jitter(%)'])

# %%
sns.distplot(df['MDVP:Jitter(Abs)'])

# %%
sns.distplot(df['MDVP:RAP'])

# %%
sns.distplot(df['MDVP:PPQ'])

# %%
sns.distplot(df['Jitter:DDP'])

# %%
sns.distplot(df['MDVP:Shimmer'])

# %%
sns.distplot(df['MDVP:Shimmer(dB)'])

# %%
sns.distplot(df['Shimmer:APQ3'])

# %%
sns.distplot(df['Shimmer:APQ5'])

# %%
sns.distplot(df['MDVP:APQ'])

# %%
sns.distplot(df['Shimmer:DDA'])

# %%
sns.distplot(df['NHR'])

# %%
sns.distplot(df['HNR'])

# %%
sns.distplot(df['RPDE'])

# %%
sns.distplot(df['D2'])

# %%
sns.distplot(df['DFA'])

# %%
sns.distplot(df['spread1'])

# %%
sns.distplot(df['spread2'])

# %%
sns.distplot(df['PPE'])

# %% [markdown]
# ### The attributes MDVP:Flo(Hz), MDVP:Jitter(%), MDVP:Jitter(Abs), MDVP:RAP, MDVP:PPQ, Jitter:DDP, spread1, spread2, D2, PPE, looks normally distributed.
# ### The attributes MDVP:Fo(Hz), MDVP:Fhi(Hz), MDVP:APQ have right tailed distribution.¶
# ### The attributes MDVP:Fhi(Hz), HNR, RPDE, DFA have multimodal distribution.
# ### The attributes MDVP:Shimmer, MDVP:Shimmer(dB), Shimmer:APQ3, Shimmer:APQ5, Shimmer:DDA, NHR have exponential distribution.

# %%
sns.boxplot(df['MDVP:Fo(Hz)'])

# %%
sns.boxplot(df['MDVP:Fhi(Hz)'])

# %%
sns.boxplot(df['MDVP:Flo(Hz)'])

# %%
sns.boxplot(df['MDVP:Jitter(%)'])

# %%
sns.boxplot(df['MDVP:Jitter(Abs)'])

# %%
sns.boxplot(df['MDVP:RAP'])

# %%
sns.boxplot(df['MDVP:PPQ'])

# %%
sns.boxplot(df['Jitter:DDP'])

# %%
sns.boxplot(df['MDVP:Shimmer'])

# %%
sns.boxplot(df['MDVP:Shimmer(dB)'])

# %%
sns.boxplot(df['Shimmer:APQ3'])

# %%
sns.boxplot(df['Shimmer:APQ5'])

# %%
sns.boxplot(df['MDVP:APQ'])

# %%
sns.boxplot(df['Shimmer:DDA'])

# %%
sns.boxplot(df['NHR'])

# %%
sns.boxplot(df['HNR'])

# %%
sns.boxplot(df['RPDE'])

# %%
sns.boxplot(df['D2'])

# %%
sns.boxplot(df['DFA'])

# %%
sns.boxplot(df['spread1'])

# %%
sns.boxplot(df['spread2'])

# %%
sns.boxplot(df['PPE'])

# %% [markdown]
# ### All attributes except RPDE, DFA and MDVP:Flo(Hz) have outliers

# %%
sns.countplot(df['status'])

# %% [markdown]
# ### As status being the target attribute, this will lead to accurate prediction for data having status 1 rather than 0

# %%
sns.pairplot(df, hue='status')

# %%
import matplotlib.pyplot as plt
plt.subplots(figsize=(20,20))
sns.heatmap(df.corr(), annot=True)

# %% [markdown]
# # 4. Split the dataset into training and test set in the ratio of 70:30 (Training:Test).

# %%
from sklearn.model_selection import train_test_split
x = df.drop(['name', 'status'], axis=1)
y = df['status']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.3, random_state=100)

# %% [markdown]
# # 5. Create the model using “entropy” method of reducing the entropy and fit it to training data. (5 points)

# %%
from sklearn.tree import DecisionTreeClassifier
dt_model = DecisionTreeClassifier(criterion='entropy')
dt_model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %% [markdown]
# # 6. Test the model on test data and what is the accuracy achieved. Capture the predicted values and do a crosstab. (7.5 points)

# %%
print('Test : ', dt_model.score(x_test , y_test))
print('Train : ', dt_model.score(x_train , y_train))
# Out:
# Test :  0.7457627118644068
# Train :  1.0

# %%
y_predict = dt_model.predict(x_test)
print(metrics.confusion_matrix(y_test, y_predict))
# Out:
# [[ 7  5]
#  [10 37]]

# %%
pd.crosstab(y_test, y_predict,
            rownames=['True'], colnames=['Predicted'])
# Out:
# Predicted   0   1
# True
# 0           7   5
# 1          10  37

# %% [markdown]
# ### The mean accuracy is 0.75, there are 5 counts of false positive results and 10 counts of false negative results

# %% [markdown]
# # 7. Use regularization parameters of max_depth, min_sample_leaf to recreate the model. What is the impact on the model accuracy? How does regularization help? (20 points)

# %%
dt_model2 = DecisionTreeClassifier(criterion='entropy', max_depth=5, max_leaf_nodes=2)
dt_model2.fit(x_train,y_train)

print('Testing accuracy : ', dt_model2.score(x_test , y_test))
print('Training accuracy : ', dt_model2.score(x_train , y_train))
# Out:
# Testing accuracy :  0.576271186440678
# Training accuracy :  0.7352941176470589

# %%
dt_model3 = DecisionTreeClassifier(criterion='entropy', max_depth=5, max_leaf_nodes=5)
dt_model3.fit(x_train,y_train)

print('Testing accuracy : ', dt_model3.score(x_test , y_test))
print('Training accuracy : ', dt_model3.score(x_train , y_train))
# Out:
# Testing accuracy :  0.7288135593220338
# Training accuracy :  0.9411764705882353

# %%
dt_model4 = DecisionTreeClassifier(criterion='entropy', max_depth=5, max_leaf_nodes=10)
dt_model4.fit(x_train,y_train)

print('Testing accuracy : ', dt_model4.score(x_test , y_test))
print('Training accuracy : ', dt_model4.score(x_train , y_train))
# Out:
# Testing accuracy :  0.6949152542372882
# Training accuracy :  0.9705882352941176

# %%
dt_model5 = DecisionTreeClassifier(criterion='entropy', max_depth=5, max_leaf_nodes=15)
dt_model5.fit(x_train,y_train)

print('Testing accuracy : ', dt_model5.score(x_test , y_test))
print('Training accuracy : ', dt_model5.score(x_train , y_train))
# Out:
# Testing accuracy :  0.6949152542372882
# Training accuracy :  0.9705882352941176

# %% [markdown]
# ### From the above models, we can see that the model started overfitting from max_leaf node size 10 onwards, so the ideal no of leaf nodes is between 5 to 10

# %% [markdown]
# # 8. Next implement the Random Forest model and find the accuracy (10 points)

# %%
from sklearn.ensemble import RandomForestClassifier
random_forest = RandomForestClassifier()

# %%
random_forest.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import accuracy_score

y_predict = random_forest.predict(x_test)

print ('Training Accuracy:',random_forest.score(x_train, y_train))
print ('Testing Accuracy:', random_forest.score(x_test, y_test))
# Out:
# Training Accuracy: 1.0
# Testing Accuracy: 0.864406779661017

# %%
from sklearn.metrics import confusion_matrix

pd.DataFrame(
    confusion_matrix(y_test, y_predict),
    columns=['Predicted Healthy', 'Predicted Parkinsons'],
    index=['True Healthy', 'True Parkinsons']
)
# Out:
#                  Predicted Healthy  Predicted Parkinsons
# True Healthy                     8                     4
# True Parkinsons                  4                    43
